# %% [markdown]
# <a href="https://colab.research.google.com/github/BI-DS/ELE-3909/blob/master/lecture7/clustering_pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
from numpy import linalg as LA
import seaborn as sns; sns.set()
from sklearn.decomposition import PCA
from IPython.core.pylabtools import figsize

# %% [markdown]
# ## Clustering with PCA 🔥

# %%
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data

# %% [markdown]
# PCA with `sklearn`is stright forward

# %%
pca = PCA(n_components=2).fit(X)
pca_2d = pca.transform(X)

# %% [markdown]
# ✅ Now lets plot the two principal components 🔥

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
ax[0].set_xlabel('Principal component 1')
ax[0].set_ylabel('Principal component 2')
ax[0].set_title('2 Dim space')
ax[0].scatter(pca_2d[:, 0], pca_2d[:, 1], c='#663399', alpha=0.5)


ax[1].set_xlabel('Principal component 1')
ax[1].set_ylabel('Principal component 2')
ax[1].set_title('Cluster labels')
ax[1].scatter(pca_2d[pca_2d[:,0]<-1.5, 0], pca_2d[pca_2d[:,0]<-1.5, 1], c='red', alpha=0.5)
ax[1].scatter(pca_2d[pca_2d[:,0]>-1.5, 0], pca_2d[pca_2d[:,0]>-1.5, 1], c='blue', alpha=0.5)
plt.savefig('pca_clust.pdf')
plt.show()

# %%
print("The first 2 components explained {:.2%} of \
the data variability".format(pca.explained_variance_ratio_.sum()))
# Out:
# The first 2 components explained 97.77% of the data variability
